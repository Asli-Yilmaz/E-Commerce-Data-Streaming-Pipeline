# %% [markdown]
# # Setup

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install pyspark==3.5.0
# !pip install kafka-python
# !pip install pymongo[srv] dnspython
# Out:
# Collecting pyspark==3.5.0
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.7 (from pyspark==3.5.0)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 12.5 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425346 sha256=a39be01a12ae6d9a59a39a5d418956b0d9033514fb5e7ce4925bf2e6421243d4
#   Stored in directory: /root/.cache/pip/wheels/84/40/20/65eefe766118e0a8f8e385cc3ed6e9eb7241c7e51cfc04c51a
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.9
#     Uninstalling py4j-0.10.9.9:
#       Successfully uninstalled py4j-0.10.9.9
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 4.0.1
#     Uninstalling pyspark-4.0.1:
#       Successfully uninstalled pyspark-4.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 1.0.1 requires pyspark[connect]~=4.0.0, but you have pyspark 3.5.0 which is incompatible.
# Successfully installed py4j-0.10.9.7 pyspark-3.5.0
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0
# Collecting dnspython
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pymongo[srv]
#   Downloading pymongo-4.15.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.15.5 does not provide the extra 'srv'
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 11.2 MB/s eta 0:00:00
# Downloading pymongo-4.15.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.5

# %%
import os
os.environ["PYSPARK_SUBMIT_ARGS"] = "--packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0 pyspark-shell"

# %%
from pyspark.sql import SparkSession
session=SparkSession.builder.appName("Kafka Projesi").getOrCreate()

# %%
# !openssl pkcs12 -export \
    -inkey service.key \
    -in service.cert \
    -out client.keystore.p12 \
    -name service_key \
    -passout pass:123456

# %% [markdown]
# # Kafka Bağlantısı

# %%
KEYSTORE_PATH = "client.keystore.p12"
KEYSTORE_PASSWORD = 123456


CA_PEM_PATH = "ca.pem"
BOOTSTRAP_SERVERS = "kafka-server-address:port"

try:
    rawDf = session.read.format("kafka") \
        .option("kafka.bootstrap.servers", BOOTSTRAP_SERVERS) \
        .option("subscribe", "ecommerce-data") \
        .option("kafka.security.protocol", "SSL") \
        .option("kafka.ssl.truststore.type", "PEM") \
        .option("kafka.ssl.truststore.location", CA_PEM_PATH) \
        .option("kafka.ssl.keystore.type", "PKCS12") \
        .option("kafka.ssl.keystore.location", KEYSTORE_PATH) \
        .option("kafka.ssl.keystore.password", KEYSTORE_PASSWORD) \
        .load()

    rawDf.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)").show(truncate=False)

except Exception as e:
    print(f"HATA: {e}")
# Out:
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |key |value                                                                                                                                                                                                         |
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# |NULL|{"OrderId":"29ecbb63-cfc9-4d1c-9f21-022539ae7954","CustomerName":"Karolann Cartwright","Product":"Tasty Frozen Chair","Price":918.08,"City":"Hammesville","OrderDate":"2025-12-25T07:58:15.2545508Z"}         |
# |NULL|{"OrderId":"83ac37c8-05c4-480d-9be4-e1afdf564eda","CustomerName":"Wilbert Casper","Product":"Generic Plastic Ball","Price":74.33,"City":"Staceyside","OrderDate":"2025-12-25T07:58:16.359723Z"}               |
# |NULL|{"OrderId":"df67682e-7b48-4219-8d1c-4db6eab5ae33","CustomerName":"Sven Romaguera","Product":"Sleek Rubber Keyboard","Price":846.68,"City":"Nolanfurt","OrderDate":"2025-12-25T07:58:17.4544674Z"}             |
# |NULL|{"OrderId":"8cce6047-f66d-4572-b73a-58943e9d6f90","CustomerName":"Lisandro Dibbert","Product":"Rustic Frozen Bike","Price":438.45,"City":"Hauckville","OrderDate":"2025-12-25T07:58:18.5514541Z"}             |
# |NULL|{"OrderId":"ff0c182d-ddf4-44b7-acbd-82b640693aea","CustomerName":"Jermain Sipes","Product":"Refined Rubber Ball","Price":444.15,"City":"Blickstad","OrderDate":"2025-12-25T07:58:19.6430322Z"}                |
# |NULL|{"OrderId":"dfe432b6-a083-4938-a2a0-71646b099689","CustomerName":"Jordan Raynor","Product":"Licensed Granite Shoes","Price":816.90,"City":"Jacobitown","OrderDate":"2025-12-25T07:58:20.7375394Z"}            |
# |NULL|{"OrderId":"83d5ada7-5ec2-4e0b-b320-07709cfea7a5","CustomerName":"Angelita Rosenbaum","Product":"Refined Soft Sausages","Price":570.50,"City":"Nolanchester","OrderDate":"2025-12-25T07:58:21.8265697Z"}      |
# |NULL|{"OrderId":"e23fa8fc-db14-4d1a-9e69-a19f732f9c4c","CustomerName":"Lance Macejkovic","Product":"Gorgeous Concrete Keyboard","Price":704.44,"City":"Port Hassanview","OrderDate":"2025-12-25T07:58:22.9181617Z"}|
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
rawDf.show(5)
# Out:
# +----+--------------------+--------------+---------+------+--------------------+-------------+
# | key|               value|         topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+--------------+---------+------+--------------------+-------------+
# |NULL|[7B 22 4F 72 64 6...|ecommerce-data|        0|     0|2025-12-25 07:58:...|            0|
# |NULL|[7B 22 4F 72 64 6...|ecommerce-data|        0|     1|2025-12-25 07:58:...|            0|
# |NULL|[7B 22 4F 72 64 6...|ecommerce-data|        0|     2|2025-12-25 07:58:...|            0|
# |NULL|[7B 22 4F 72 64 6...|ecommerce-data|        0|     3|2025-12-25 07:58:...|            0|
# |NULL|[7B 22 4F 72 64 6...|ecommerce-data|        0|     4|2025-12-25 07:58:...|            0|
# +----+--------------------+--------------+---------+------+--------------------+-------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import
------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ##En çok satan ürünler

# %%
orderDf.groupBy("Product").count().orderBy("count",ascending=False).show()
# Out:
# +--------------------+-----+
# |             Product|count|
# +--------------------+-----+
# |Generic Steel Sau...|    6|
# |Awesome Plastic T...|    6|
# |Rustic Soft Sausages|    5|
# |   Tasty Fresh Shoes|    5|
# |Incredible Cotton...|    5|
# |   Tasty Rubber Ball|    5|
# |    Sleek Soft Mouse|    5|
# | Refined Steel Chips|    5|
# |Intelligent Cotto...|    5|
# | Rustic Frozen Chair|    5|
# |Handcrafted Rubbe...|    5|
# |Unbranded Cotton ...|    5|
# |Refined Steel Gloves|    5|
# |Handcrafted Steel...|    5|
# | Unbranded Fresh Car|    4|
# |Fantastic Concret...|    4|
# | Handmade Soft Chips|    4|
# |Fantastic Frozen ...|    4|
# |Awesome Wooden Bacon|    4|
# |Ergonomic Concret...|    4|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ##Son 1 saatteki alışverişlerin listesi

# %%
last_hour_df = orderDf.filter(col("OrderDate") > current_timestamp() - expr("INTERVAL 1 HOUR"))

last_hour_df.show(truncate=False)
# Out:
# +------------------------------------+----------------------+--------------------------+--------+---------+--------------------------+
# |OrderId                             |CustomerName          |Product                   |Price   |City     |OrderDate                 |
# +------------------------------------+----------------------+--------------------------+--------+---------+--------------------------+
# |1b2db324-f505-47b1-b56b-9642cae628a1|Glenda Howell         |Refined Soft Tuna         |66305.96|Aydin    |2025-12-28 17:09:19.716925|
# |18cf1e66-b8a4-4e84-96e4-7624cbf95e58|Rosalee Langworth     |Practical Concrete Towels |24984.58|Kocaeli  |2025-12-28 17:09:22.02304 |
# |fd40f536-dc28-49a4-a2cf-d2ac8be2f10d|Trey Howell           |Handmade Concrete Fish    |30675.35|Mardin   |2025-12-28 17:09:23.122202|
# |f5885330-997c-4039-bf64-146c1a2b4a35|Meda Roberts          |Intelligent Frozen Pizza  |6884.01 |Artvin   |2025-12-28 17:09:24.218469|
# |58f787ab-08e4-4c2a-80fc-06e319bec139|Providenci Rutherford |Sleek Plastic Mouse       |39905.26|Usak     |2025-12-28 17:09:25.311453|
# |0320c9ba-3107-437a-b803-f66a22c9a598|Wellington Satterfield|Small Concrete Keyboard   |54190.02|Trabzon  |2025-12-28 17:09:26.397208|
# |3d33cf4a-9553-47cf-b7ac-29582b09ad0e|Carley Cronin         |Licensed Soft Tuna        |58190.51|Van      |2025-12-28 17:09:27.484681|
# |059cafa3-ba82-4c82-857c-a29a942a7ed1|Violet Runte          |Refined Concrete Table    |95083.39|Izmir    |2025-12-28 17:09:28.57883 |
# |03812b79-7236-4f9a-816b-2d655f501f85|Joaquin Murray        |Sleek Concrete Fish       |99326.43|Agri     |2025-12-28 17:09:29.68593 |
# |56078efd-09fc-42f6-a76c-92314f7fb2fd|Jeff Hoeger           |Tasty Steel Hat           |65445.92|Artvin   |2025-12-28 17:09:30.768623|
# |c3684e7a-001c-4ae3-ab2d-3ba051a34b2b|Alyce Wiegand         |Practical Plastic Computer|54890.03|Bitlis   |2025-12-28 17:09:31.856828|
# |6f5cdc87-780b-483a-9388-446fa03c702d|Kariane Wintheiser    |Licensed Soft Gloves      |22562.52|Tunceli  |2025-12-28 17:09:32.9465  |
# |245f348d-7763-4954-88a7-bde8e039b759|Joannie Jacobi        |Incredible Steel Ball     |68886.37|Bitlis   |2025-12-28 17:09:34.032209|
# |ea899bf2-671f-48ec-aa5e-1176d535793d|Arno Ledner           |Awesome Cotton Chicken    |36049.02|Ankara   |2025-12-28 17:09:35.122707|
# |550eacd9-162d-4fad-9ff7-5913ca92e87d|Deangelo Haag         |Intelligent Cotton Chips  |52000.41|Erzurum  |2025-12-28 17:09:36.223395|
# |bd4aab06-214c-45b0-8006-5f73e9a75568|Forrest Davis         |Incredible Steel Salad    |51894.17|Cankiri  |2025-12-28 17:09:37.310512|
# |47d1496f-ec14-4d3d-b015-1f23ee104f7c|Conor Schroeder       |Sleek Wooden Towels       |92926.66|Kastamonu|2025-12-28 17:09:38.414978|
# |38f4671a-7fe1-4ef2-bff8-47c9fe37e535|Cathy Keeling         |Awesome Concrete Gloves   |5564.4  |Ardahan  |2025-12-28 17:09:39.519667|
# |d429fb7f-4a99-42fa-ab60-d60ddc52c870|Salvatore Lind        |Ergonomic Wooden Salad    |48465.47|Malatya  |2025-12-28 17:09:40.621902|
# |8bfe122f-5c2c-44a7-bff9-b4b9c54a1e64|Jaime Bailey          |Incredible Wooden Bike    |22910.58|Yalova   |2025-12-28 17:09:41.708054|
# +------------------------------------+----------------------+--------------------------+--------+---------+--------------------------+
# only showing top 20 rows

# %% [markdown]
#  ## Son 1 saatteki alışverişlerin sayısı

# %%
last_hour_df.count()
# Out:
# 229

# %% [markdown]
# # Stream veri için Kafka bağlantısı

# %%
rawDf = session.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", BOOTSTRAP_SERVERS) \
    .option("subscribe", "ecommerce-data") \
    .option("kafka.security.protocol", "SSL") \
    .option("kafka.ssl.truststore.type", "PEM") \
    .option("kafka.ssl.truststore.location", CA_PEM_PATH) \
    .option("kafka.ssl.keystore.type", "PKCS12") \
    .option("kafka.ssl.keystore.location", KEYSTORE_PATH) \
    .option("kafka.ssl.keystore.password", KEYSTORE_PASSWORD) \
    .option("startingOffsets", "latest") \
    .load()


df_parsed = rawDf.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")


query = df_parsed.writeStream \
    .outputMode("append") \
    .format("memory") \
    .queryName("orders") \
    .start()

# %%
df = session.table("orders")

df.show(5, truncate=False)
# Out:
# +------------------------------------+-----------------+---------------------+--------+---------+--------------------------+
# |OrderId                             |CustomerName     |Product              |Price   |City     |OrderDate                 |
# +------------------------------------+-----------------+---------------------+--------+---------+--------------------------+
# |56aa7fef-b8ea-47d7-bd90-0b96bffbf748|Alycia Bartoletti|Handmade Frozen Shirt|31431.76|Usak     |2025-12-28 17:13:47.960944|
# |6c08b7d2-cbb3-4f20-9be3-fccc3d62084a|Cindy Conroy     |Gorgeous Steel Tuna  |25946.59|Karaman  |2025-12-28 17:13:49.063792|
# |25de2cf8-9c74-4b7c-9f9d-f1ebb3508451|Arno Senger      |Small Wooden Car     |20027.87|Ordu     |2025-12-28 17:13:50.142414|
# |a3a96cdf-0f1f-4584-8a39-d53d6f9d410a|Deon Little      |Practical Cotton Bike|63293.49|Rize     |2025-12-28 17:13:51.230784|
# |21d3822a-fade-4831-9cad-097bf3cc770b|Raheem Daniel    |Small Plastic Bacon  |82309.37|Gaziantep|2025-12-28 17:13:52.328318|
# +------------------------------------+-----------------+---------------------+--------+---------+--------------------------+
# only showing top 5 rows

# %% [markdown]
# # Stream veri analizi

# %% [markdown]
# ## Stream veri sayısı

# %%
df.count()
# Out:
# 306

# %% [markdown]
# ## Steam verilere göre anlık olarak yapılan en pahalı alışverişler

# %%
df.orderBy("Price",ascending=False).show()
# Out:
# +--------------------+-----------------+--------------------+--------+---------+--------------------+
# |             OrderId|     CustomerName|             Product|   Price|     City|           OrderDate|
# +--------------------+-----------------+--------------------+--------+---------+--------------------+
# |eb20ebf9-d306-426...|       Zane Upton|Ergonomic Rubber ...|99681.12|Kirikkale|2025-12-28 17:15:...|
# |8a4a0b35-2f9c-45a...|  Reina Kertzmann|Ergonomic Metal G...|99238.16|      Mus|2025-12-28 17:17:...|
# |9fdac3ce-bd3b-497...|    Rebeka Carter|Small Plastic Chi...|98773.49|    Hatay|2025-12-28 17:14:...|
# |8c6bc2ce-6403-446...| Abraham Baumbach|Generic Cotton Ch...|97973.23| Adiyaman|2025-12-28 17:15:...|
# |96f8005e-9724-42e...|   Randal Ziemann|Sleek Cotton Keyb...|97595.11|   Samsun|2025-12-28 17:14:...|
# |88f07b6c-b937-4ef...|      Benton Lind|Rustic Rubber Chi...|97417.89|   Mersin|2025-12-28 17:18:...|
# |dce74be7-4291-489...| Brendan Nitzsche|Small Granite Gloves|96822.89| Tekirdag|2025-12-28 17:14:...|
# |477c2e0f-142f-4c1...|  Vallie Dietrich|  Sleek Metal Towels|96581.15| Adiyaman|2025-12-28 17:18:...|
# |389129bc-9063-4a6...|Carmelo Daugherty|Licensed Plastic ...|95901.02|   Artvin|2025-12-28 17:18:...|
# |47f6b892-4a2f-489...|  Jaden Gutkowski|   Awesome Soft Bike|95827.51|    Kilis|2025-12-28 17:17:...|
# |467605b0-249f-4e4...|      Renee Thiel|Handcrafted Concr...|95668.07| Adiyaman|2025-12-28 17:15:...|
# |279ccd2d-cec8-494...| Florida O'Reilly| Awesome Fresh Pizza|95410.17|     Agri|2025-12-28 17:18:...|
# |94e47ed8-2656-477...|    Laurie Gibson| Small Granite Salad|94916.71|  Isparta|2025-12-28 17:17:...|
# |2add2112-e521-49f...|  Muhammad Raynor| Rustic Granite Tuna|94615.75|   Bartin|2025-12-28 17:17:...|
# |cbf40895-bf85-459...|Marcelina Simonis|Handcrafted Soft ...| 94605.9|  Hakkari|2025-12-28 17:19:...|
# |c0d59ea6-a8f0-436...|         Eli Mraz|     Rustic Soft Hat|94425.89|Zonguldak|2025-12-28 17:16:...|
# |3226dc9b-12ae-4eb...|      Reyes Koepp|Ergonomic Cotton ...|94374.42|Eskisehir|2025-12-28 17:19:...|
# |ae6cdc92-b0a9-42d...|    Jalyn Padberg|Unbranded Soft Pants|93847.42|   Bartin|2025-12-28 17:16:...|
# |579815bc-9007-477...|     Loyal Sporer|Gorgeous Concrete...|93408.08|  Ardahan|2025-12-28 17:17:...|
# |33e897d4-bac2-419...|      Roy Hackett|Incredible Wooden...|93274.47|     Bolu|2025-12-28 17:18:...|
# +--------------------+-----------------+--------------------+--------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Stream verilere göre anlık olarak en çok satılan ürünler

# %%
df.groupBy("Product").count().orderBy("count",ascending=False).show()
# Out:
# +--------------------+-----+
# |             Product|count|
# +--------------------+-----+
# |   Generic Steel Hat|    2|
# | Generic Steel Chair|    2|
# |Intelligent Froze...|    2|
# |Small Granite Gloves|    2|
# |Unbranded Frozen ...|    2|
# |Fantastic Plastic...|    2|
# |Licensed Metal Mouse|    2|
# | Sleek Plastic Chips|    2|
# |    Rustic Metal Hat|    2|
# |Incredible Metal ...|    2|
# |Ergonomic Metal Tuna|    2|
# |Handmade Cotton S...|    1|
# |    Sleek Frozen Car|    1|
# | Small Wooden Cheese|    1|
# |Rustic Cotton Cheese|    1|
# |Awesome Concrete ...|    1|
# |Incredible Wooden...|    1|
# |Handmade Steel Sa...|    1|
# |  Sleek Rubber Bacon|    1|
# |Unbranded Rubber ...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## Stream verilere göre anlık olarak en çok alışveriş yapılan şehirler

# %%
df.groupBy("City").count().orderBy("count",ascending=False).show()
# Out:
# +----------+-----+
# |      City|count|
# +----------+-----+
# |Kirklareli|    8|
# |  Nevsehir|    8|
# |     Sivas|    7|
# |     Tokat|    7|
# |    Elazig|    7|
# |    Samsun|    7|
# |   Isparta|    6|
# |    Edirne|    6|
# |   Kutahya|    6|
# |       Mus|    6|
# | Canakkale|    6|
# | Gaziantep|    6|
# |   Kayseri|    5|
# | Balikesir|    5|
# |     Igdir|    5|
# |     Hatay|    5|
# |     Corum|    5|
# |    Yalova|    5|
# |  Kirsehir|    5|
# |     Siirt|    5|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# ## Stream verilere göre anlık olarak en çok harcama yapan şehirler

# %%
df.groupBy("City").sum("Price").orderBy("sum(Price)",ascending=False).show()
# Out:
# +----------+------------------+
# |      City|        sum(Price)|
# +----------+------------------+
# |Kirklareli|         465504.05|
# |  Nevsehir|          452996.2|
# |     Tokat|         450592.76|
# |    Samsun|         427785.12|
# | Canakkale|370323.45000000007|
# |    Elazig|         334358.61|
# |      Bolu|         312222.61|
# | Kirikkale|         310584.61|
# |    Edirne|         296165.99|
# |  Adiyaman|290222.44999999995|
# |   Isparta|289148.91000000003|
# |      Agri|288928.43000000005|
# |    Artvin|         284223.06|
# |     Izmir|280719.29000000004|
# |   Kayseri|         273621.34|
# |Diyarbakir|         269126.81|
# | Gumushane|         268453.11|
# | Gaziantep|         266463.95|
# |    Bartin|261372.09999999998|
# |     Bursa|         254600.68|
# +----------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Stream verilere göre anlık olarak en çok alışveriş yapan müşteriler

# %%
df.groupBy("CustomerName").count().orderBy("count",ascending=False).show()
# Out:
# +-----------------+-----+
# |     CustomerName|count|
# +-----------------+-----+
# |     Paolo Maggio|    1|
# |     Ernest Ortiz|    1|
# |   Vincent Waters|    1|
# |     Robin Heaney|    1|
# |   Amie O'Connell|    1|
# |    Makayla Bauch|    1|
# |Jerrold O'Connell|    1|
# |   Karlie Lebsack|    1|
# |        Lily Veum|    1|
# |     Anne Bradtke|    1|
# |       Flo Deckow|    1|
# |     Theresa Rowe|    1|
# |   Elian Franecki|    1|
# | Maryjane Kilback|    1|
# |  Bradley Spencer|    1|
# |      Keyon Braun|    1|
# | Jackeline Herzog|    1|
# |       Tony Purdy|    1|
# |        Kyle Moen|    1|
# |        Ivy Bauch|    1|
# +-----------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Şüpheli işlemlerin tespiti

# %%
import pymongo

MONGO_URI ="mongodb+srv:uri"

# %%
stats_df = session.sql("""
    SELECT
        City,
        AVG(Price) as RefMean,
        STDDEV(Price) as RefStdDev
    FROM orders
    GROUP BY City
""")
stats_df.cache()
stats_df.count()
# Out:
# 0

# %% [markdown]
# ## Şüpheli işlemlerin MongoDB'ye kaydedilmesi

# %%
def write_anomalies_to_mongo(batch_df, epoch_id):
    if batch_df.count() == 0:
        return

    batch_df.cache()

    checked_df = batch_df.join(stats_df, "City", "left")

    anomalies = checked_df.filter(
        col("Price") > (col("RefMean") + (2 * col("RefStdDev")))
    )

    count = anomalies.count()
    if count > 0:

        try:
            data_to_save = [row.asDict() for row in anomalies.collect()]


            client = pymongo.MongoClient(MONGO_URI)
            db = client["EcommerceDB"]
            collection = db["FraudAlerts"]


            collection.insert_many(data_to_save)

            client.close()

        except Exception as e:
            print(f"Hata: {e}")

    batch_df.unpersist()

# %%
query_mongo = df_parsed.writeStream \
    .outputMode("append") \
    .foreachBatch(write_anomalies_to_mongo) \
    .start()

# %% [markdown]
# ## MongoDB'ye olan stream işleminin durdurulması

# %%
query_mongo.stop()
